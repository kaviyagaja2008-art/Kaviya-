# %% [markdown]
# <a href="https://colab.research.google.com/github/kaviyagaja2008-art/Kaviya-/blob/main/Hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# List of 5 words
words = ["apple", "tiger", "chair", "house", "water"]

# Select a random word
word = random.choice(words)

guessed_word = ["_"] * len(word)
wrong_guesses = 0
max_wrong_guesses = 6

print("🎮 Welcome to Hangman Game!")

while wrong_guesses < max_wrong_guesses and "_" in guessed_word:

    print("\nWord:", " ".join(guessed_word))
    print("Wrong guesses left:", max_wrong_guesses - wrong_guesses)

    guess = input("Guess a letter: ").lower()

    if guess in word:
        print("Correct guess!")

        for i in range(len(word)):
            if word[i] == guess:
                guessed_word[i] = guess

    else:
        print("Wrong guess!")
        wrong_guesses += 1

if "_" not in guessed_word:
    print("\n🎉 You won!")
    print("The word was:", word)
else:
    print("\n❌ Game Over!")
    print("The word was:", word)
# Out:
# 🎮 Welcome to Hangman Game!
#
# Word: _ _ _ _ _
# Wrong guesses left: 6
# Guess a letter: A
# Wrong guess!
#
# Word: _ _ _ _ _
# Wrong guesses left: 5
# Guess a letter: I
# Wrong guess!
#
# Word: _ _ _ _ _
# Wrong guesses left: 4
# Guess a letter: P
# Wrong guess!
#
# Word: _ _ _ _ _
# Wrong guesses left: 3
# Guess a letter: O
# Correct guess!
#
# Word: _ o _ _ _
# Wrong guesses left: 3
# Guess a letter: H
# Correct guess!
#
# Word: h o _ _ _
# Wrong guesses left: 3
# Guess a letter: U
# Correct guess!
#
# Word: h o u _ _
# Wrong guesses left: 3
# Guess a letter: S
# Correct guess!
#
# Word: h o u s _
# Wrong guesses left: 3
# Guess a letter: E
# Correct guess!
#
# 🎉 You won!
# The word was: house
